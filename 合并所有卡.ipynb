# %%
#开户信息
import pandas as pd
from pathlib import Path
import re
def insert_name(name):
    # 为csv文件添加文件名列
    df_temp = pd.read_csv(name, encoding="ANSI")
    df_temp.insert(0, "文件名", name.stem)
    df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
     #df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
    for i in range(len(list(df_temp.columns))):
        
        df_temp.iloc[:,i]=df_temp.iloc[:,i].str.strip()
       
        #df_temp.iloc[:,7:8]=df_temp.iloc[:,:].astype("string")    
    return df_temp
# 合并csv文件
hb=[]
path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'
for index,name in enumerate(Path(path).glob("*[!子]账户*.csv")):
    
    df=insert_name(name)
    hb.append(df)
data_kaihu=pd.concat(hb)
data_kaihu.columns=data_kaihu.columns.str.strip()
data_kaihu.insert(0, "包名", os.path.basename(path))
# with pd.ExcelWriter(r"C:\Users\23934\Desktop\彩神\重新分析2-4\427开户信息.xlsx") as writer:
#      data_kaihu.to_excel(writer, sheet_name="data_kaihu",index=False)  
#     data_kh_qka.to_excel(writer, sheet_name="data_kh_qka",index=False)

# %%
data_kaihu
# Out:
#                         包名                   文件名 账户开户名称             开户人证件号码  \
# 0   5111057420220424163132    上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 1   5111057420220424163132    上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 2   5111057420220424163132    上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 0   5111057420220424163132    上海浦东发展银行股份有限公司账户信息    道古尔  652223198808151210
# 1   5111057420220424163132    上海浦东发展银行股份有限公司账户信息     黄超  421083199209174919
# ..                     ...                   ...    ...                 ...
# 2   5111057420220424163132       浙江省农村信用社联合社账户信息    王梦杰  330206198304040311
# 0   5111057420220424163132  湖北荆州农村商业银行股份有限公司账户信息
# 0   5111057420220424163132     湖南省农村信用合作社联合社账户信息    杨中铸  430181198402283358
# 0   5111057420220424163132       贵州省农村信用社联合社账户信息      -                   -
# 0   5111057420220424163132        长沙银行股份有限公司账户信息     肖浩  432503199502085016
#
#                    交易卡号                  交易账号    账号开户时间     账户余额 可用余额   币种  \
# 0   6231626031033503198     32181370001904620  20130212      0.0  0.0  CNY
# 1   6231626031033503198     79931000652640465  20180309      0.0  0.0  CNY
# 2   6231626031033503198     79931000830460604  20201121      0.0  0.0  CNY
# 0      6217923070815344  60040066601500122144  20211206    98.69       CNY
# 1      6217922158136466  70070066601100188050  20190330   112.78       CNY
# ..                  ...                   ...       ...      ...  ...  ...
# 2   6230910299077583940       101017345873612  20210814  3088.28       CNY
# 0      6210134947962593     81010000744229946               -1.0
# 0   6230901818135181719   6230901818135181719  20070425     0.73       CNY
# 0                     -   6217796630002106858
# 0   6214467873201170997   6214467873201170997  20201028   300.22       CNY
#
#     ... 单位电话 代办人证件类型 住宅电话 法人代表证件类型 国税纳税号 单位地址 工作单位 销户网点                最后交易时间  \
# 0   ...                                                   2013-02-14 00:00:00
# 1   ...
# 2   ...
# 0   ...                                                   2022-04-17 12:47:55
# 1   ...                                                   2022-04-22 10:13:52
# ..  ...  ...     ...  ...      ...   ...  ...  ...  ...                   ...
# 2   ...                                                   2022-04-21 02:50:37
# 0   ...                                                  10000-10-31 00:00:00
# 0   ...                                                   2022-04-25 00:00:00
# 0   ...
# 0   ...                                                   2022-04-20 00:00:00
#
#    账户销户银行
# 0
# 1
# 2
# 0
# 1
# ..    ...
# 2
# 0
# 0
# 0
# 0
#
# [241 rows x 45 columns]

# %%
import os
path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'
c= os.path.basename(path2)
print(c)path
# Out:
# 5111057420220424163132

# %%
#开户信息
import os
import pandas as pd
from pathlib import Path
import re
def insert_name(name):
    # 为csv文件添加文件名列
    df_temp = pd.read_csv(name, encoding="ANSI")
    df_temp.insert(0, "文件名", name.stem)
    df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
     #df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
    for i in range(len(list(df_temp.columns))):
        
        df_temp.iloc[:,i]=df_temp.iloc[:,i].str.strip()
       
        #df_temp.iloc[:,7:8]=df_temp.iloc[:,:].astype("string")    
    return df_temp
# 合并csv文件

data=[]
paths=[r"C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132",r"C:\Users\23934\Desktop\彩神\过程\彩神\57-收款卡1层\5.7\5111057420220506153745",r"C:\Users\23934\Desktop\彩神\过程\彩神\523-收款卡3层\5111057420220519105010",r"C:\Users\23934\Desktop\彩神\过程\彩神\523-收款卡3层\5111057420220519145929",r"C:\Users\23934\Desktop\彩神\过程\彩神\三方那一层\5111057420220524164041",r"C:\Users\23934\Desktop\彩神\过程\彩神\5111057420220526150912",r"C:\Users\23934\Desktop\彩神\过程\彩神\5111057420220527153115"]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'
for path in paths:
    hb=[]
    for index,name in enumerate(Path(path).glob("*[!子]账户*.csv")):

        df=insert_name(name)
        hb.append(df)
    data_kaihu=pd.concat(hb)
    data_kaihu.columns=data_kaihu.columns.str.strip()
    data_kaihu.insert(0, "包名", os.path.basename(path))
    data.append(data_kaihu)

# %%
data_kaxx=pd.concat(data)

# %%
data_kaxx.drop_duplicates()
# Out:
#                         包名                 文件名 账户开户名称             开户人证件号码  \
# 0   5111057420220424163132  上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 1   5111057420220424163132  上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 2   5111057420220424163132  上海农村商业银行股份有限公司账户信息     毛伟  421003198709270011
# 0   5111057420220424163132  上海浦东发展银行股份有限公司账户信息    道古尔  652223198808151210
# 1   5111057420220424163132  上海浦东发展银行股份有限公司账户信息     黄超  421083199209174919
# ..                     ...                 ...    ...                 ...
# 0   5111057420220527153115            平安银行账户信息    马进军  370121197607153955
# 0   5111057420220527153115      招商银行股份有限公司账户信息    刘术华  511324198507154864
# 1   5111057420220527153115      招商银行股份有限公司账户信息    王晓丽  130104199105131228
# 0   5111057420220527153115      浙商银行股份有限公司账户信息     曾志  350822198608262219
# 0   5111057420220527153115     浙江省农村信用社联合社账户信息     邹祥  421024198510172096
#
#                    交易卡号                  交易账号    账号开户时间     账户余额 可用余额   币种  \
# 0   6231626031033503198     32181370001904620  20130212      0.0  0.0  CNY
# 1   6231626031033503198     79931000652640465  20180309      0.0  0.0  CNY
# 2   6231626031033503198     79931000830460604  20201121      0.0  0.0  CNY
# 0      6217923070815344  60040066601500122144  20211206    98.69       CNY
# 1      6217922158136466  70070066601100188050  20190330   112.78       CNY
# ..                  ...                   ...       ...      ...  ...  ...
# 0   6230583615154101866   6230583615154101866  20161008
# 0      6214862892496888       128174665100001  20110731     0.75       CNY
# 1      6214833110616516       311011014120001  20150320  2526.09       CNY
# 0   6223095510010228027   6223095510010228027  20220511   1507.0       CNY
# 0   6230910399130893904       101016537773562  20200521      0.0       CNY
#
#     ... 单位电话 代办人证件类型 住宅电话 法人代表证件类型 国税纳税号 单位地址 工作单位 销户网点               最后交易时间  \
# 0   ...                                                  2013-02-14 00:00:00
# 1   ...
# 2   ...
# 0   ...                                                  2022-04-17 12:47:55
# 1   ...                                                  2022-04-22 10:13:52
# ..  ...  ...     ...  ...      ...   ...  ...  ...  ...                  ...
# 0   ...                                                  2022-05-26 01:01:01
# 0   ...                                                  2022-05-25 00:00:00
# 1   ...                                                  2022-05-13 00:00:00
# 0   ...                                                  2022-05-23 21:25:45
# 0   ...                                                  2022-05-23 11:30:39
#
#    账户销户银行
# 0
# 1
# 2
# 0
# 1
# ..    ...
# 0
# 0
# 1
# 0
# 0
#
# [979 rows x 45 columns]

# %%
#开户信息
import pandas as pd
from pathlib import Path
import re
def insert_name(name):
    # 为csv文件添加文件名列
    df_temp = pd.read_csv(name, encoding="ANSI")
    df_temp.insert(0, "文件名", name.stem)
    df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
     #df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
    for i in range(len(list(df_temp.columns))):
        
        df_temp.iloc[:,i]=df_temp.iloc[:,i].str.strip()
       
        #df_temp.iloc[:,7:8]=df_temp.iloc[:,:].astype("string")    
    return df_temp
# 合并csv文件

data=[]
paths=[r"C:\Users\23934\Desktop\彩神\重新分析2-4\5111057420220808164314",r"C:\Users\23934\Desktop\彩神\过程\刘sir发的卡\5111057420220526163935代理卡",r"C:\Users\23934\Desktop\彩神\过程\刘sir发的卡\tg代付卡",r"C:\Users\23934\Desktop\彩神\过程\小苏\5111057420220601153156",r"C:\Users\23934\Desktop\彩神\过程\小苏\后台赌客卡兴业银行、建行、农行查询",r"C:\Users\23934\Desktop\彩神\718\5111057420220714154929",r"C:\Users\23934\Desktop\彩神\重新分析2-4\5111057420220808164314"]
for path in paths:
    hb=[]
    for index,name in enumerate(Path(path).glob("*[!子]账户*.csv")):

        df=insert_name(name)
        hb.append(df)
    data_kaihu=pd.concat(hb)
    data_kaihu.columns=data_kaihu.columns.str.strip()
    data_kaihu.insert(0, "包名", os.path.basename(path))
    data.append(data_kaihu)
data_kaxx1=pd.concat(data)

# %%
data_ka=pd.concat([data_kaxx,data_kaxx1])

# %%
data_ka.to_excel(r'C:\Users\23934\Desktop\彩神\所有卡\all所有卡开户信息.xlsx',index=False)

# %%
import os
data=[]
paths=[r"C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132",r"C:\Users\23934\Desktop\彩神\过程\彩神\57-收款卡1层\5.7\5111057420220506153745",r"C:\Users\23934\Desktop\彩神\过程\彩神\523-收款卡3层\5111057420220519105010",r"C:\Users\23934\Desktop\彩神\过程\彩神\523-收款卡3层\5111057420220519145929",r"C:\Users\23934\Desktop\彩神\过程\彩神\三方那一层\5111057420220524164041",r"C:\Users\23934\Desktop\彩神\过程\彩神\5111057420220526150912",r"C:\Users\23934\Desktop\彩神\过程\彩神\5111057420220527153115"]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'
for path in paths:
     data.append(os.path.basename(path))

# %%
#开户信息
import os
import pandas as pd
from pathlib import Path
import re
def insert_name(name):
    # 为csv文件添加文件名列
    df_temp = pd.read_csv(name, encoding="ANSI")
    df_temp.insert(0, "文件名", name.stem)
    df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
     #df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
    for i in range(len(list(df_temp.columns))):
        
        df_temp.iloc[:,i]=df_temp.iloc[:,i].str.strip()
       
        #df_temp.iloc[:,7:8]=df_temp.iloc[:,:].astype("string")    
    return df_temp
# 合并csv文件

data=[]
paths=[r"C:\Users\23934\Desktop\彩神\流水原包\5108810020220826102205"]
for path in paths:
    hb=[]
    for index,name in enumerate(Path(path).glob("*[!子]账户*.csv")):

        df=insert_name(name)
        hb.append(df)
    data_kaihu=pd.concat(hb)
    data_kaihu.columns=data_kaihu.columns.str.strip()
    data_kaihu.insert(0, "包名", os.path.basename(path))
    data.append(data_kaihu)
data_kaxx1=pd.concat(data)

# %%
data_kaxx1.to_excel(r"C:\Users\23934\Desktop\彩神\分析\分析流水\830开户信息.xlsx", sheet_name="830ls",index=False)

# %%
#开户信息
import pandas as pd
from pathlib import Path
import re
def insert_name(name):
    # 为csv文件添加文件名列
    df_temp = pd.read_csv(name, encoding="ANSI")
    df_temp.insert(0, "文件名", name.stem)
    df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
     #df_temp.iloc[:,:]=df_temp.iloc[:,:].astype("string")
    for i in range(len(list(df_temp.columns))):
        
        df_temp.iloc[:,i]=df_temp.iloc[:,i].str.strip()
       
        #df_temp.iloc[:,7:8]=df_temp.iloc[:,:].astype("string")    
    return df_temp
# 合并csv文件
hb=[]
for index,name in enumerate(Path(r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132').glob("*[!子]账户*.csv")):
    
    df=insert_name(name)
    hb.append(df)
data_kaihu=pd.concat(hb)
data_kaihu.columns=data_kaihu.columns.str.strip()
data_kh_qka=data_kaihu.copy(deep=True)
#data_kaihu['交易卡号']=data_kaihu['交易卡号'].apply(lambda x:x[0])
#data_kaihu.to_excel(r'C:\Users\23934\Desktop\彩神\小苏\lx\427赌客与收款卡开户信息lx.xlsx',sheet_name="data_kaihu",index=False)
data_kh_qka['交易卡号']=data_kh_qka['交易卡号'].apply(lambda x:re.split(r'_', x)).apply(lambda x:x[0])
#data_kh_qka.iloc[:,4]=data_kh_qka.iloc[:,4].apply(lambda x:re.split(r'_', x)).apply(lambda x:x[0])
data_kh_qka['交易账号']=data_kh_qka['交易账号'].apply(lambda x:re.split(r'_', x)).apply(lambda x:x[0])
data_kh_qka=data_kh_qka.drop_duplicates()
with pd.ExcelWriter(r"C:\Users\23934\Desktop\彩神\重新分析2-4\427开户信息.xlsx") as writer:
     data_kaihu.to_excel(writer, sheet_name="data_kaihu",index=False)  
    data_kh_qka.to_excel(writer, sheet_name="data_kh_qka",index=False)
