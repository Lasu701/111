# %%
from pathlib import Path
import pandas as pd
#pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'E:\3899\3899后台数据 2\5104188120210913171911').glob("*交易*.csv"))],ignore_index =True).to_csv("result.csv",index = False)
df = pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'D:\仁寿\仁寿数据\收款卡\第二批收款卡调回3月24日\3.25\5111057420220324162741').glob("*[!'子']账户信息.csv"))],ignore_index =True)
df.head()
# Out:
#   账户开户名称\t             开户人证件号码\t               交易卡号\t                  交易账号\t  \
# 0    王俊杰\t    420115199611120036     6217922159211631  70240066601200022016\t
# 1    方春稀\t    340503196605210425     6217924070070500  34070066601300161044\t
# 2    鲍尤绿\t    320722196808183048     6226632001599476        6226632001599476
# 3    张苗苗\t  22018219950305314X\t  6228480039451041170     6228480039451041170
# 4    闫宇豪\t  142201200502220035\t  6230521660032657577     6230521660032657577
#
#    账号开户时间\t  账户余额\t 可用余额\t   币种\t      开户网点代码\t                 开户网点\t  ...  \
# 0  20210226   10.73     \t  CNY\t  310521000242           浦发银行武汉江夏支行\t  ...
# 1  20220104     0.0     \t  CNY\t  310641000069          浦发银行海口金盘路支行\t  ...
# 2  20220124  798.52     \t  CNY\t          5797                 东海支行\t  ...
# 3  20211214  222.28     \t  CNY\t         94116  中国农业银行股份有限公司上海马戏城支行\t  ...
# 4  20211204    11.7     \t  CNY\t         46790   中国农业银行股份有限公司忻州七一支行\t  ...
#
# ...

# %%
from pathlib import Path
import pandas as pd
#pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'E:\3899\3899后台数据 2\5104188120210913171911').glob("*交易*.csv"))],ignore_index =True).to_csv("result.csv",index = False)
df = pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'D:\仁寿\仁寿数据\收款卡\第二批收款卡调回3月24日\3.25\5111057420220324162741').glob("*交易*.csv"))],ignore_index =True)
df[list(df.columns)[0]]=df[list(df.columns)[0]].astype(str)
df.to_excel(r'D:仁寿/小苏/李收2层2.xlsx',index=False)

# %%
from pathlib import Path
import pandas as pd
#pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'E:\3899\3899后台数据 2\5104188120210913171911').glob("*交易*.csv"))],ignore_index =True).to_csv("result.csv",index = False)
df = pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'D:\仁寿\仁寿数据\5111057420220411142244\5111057420220411142244').glob("*交易*.csv"))],ignore_index =True)
df[list(df.columns)[0]]=df[list(df.columns)[0]].astype(str)
#df.iloc[:, 0] = df.iloc[:, 0].astype('string')
df.to_excel(r'D:仁寿/小苏/李三方.xlsx',index=False)

# %%
from pathlib import Path
import pandas as pd
#pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'E:\3899\3899后台数据 2\5104188120210913171911').glob("*交易*.csv"))],ignore_index =True).to_csv("result.csv",index = False)
df = pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'D:\仁寿\仁寿数据\5111057420220411142244\5111057420220411142244').glob("*交易*.csv"))],ignore_index =True)
df
# Out:
#                         交易卡号\t                   交易账号\t 查询反馈结果原因\t 交易户名\t  \
# 0             6226632001599476         6226632001599476       成功\t     \t
# 1             6226632001599476         6226632001599476       成功\t     \t
# 2             6226632001599476         6226632001599476       成功\t     \t
# 3             6226632001599476         6226632001599476       成功\t     \t
# 4             6226632001599476         6226632001599476       成功\t     \t
# ...                        ...                      ...        ...    ...
# 71380  6230680000007708930_1\t  6230680000007708930_1\t       成功\t     \t
# 71381  6230680000007708930_1\t  6230680000007708930_1\t       成功\t     \t
# 71382  6230680000007708930_1\t  6230680000007708930_1\t       成功\t     \t
# 71383  6230680000007708930_1\t  6230680000007708930_1\t       成功\t     \t
# 71384  6230680000007708930_1\t  6230680000007708930_1\t       成功\t     \t
#
#       交易证件号码\t                 交易时间\t   交易金额\t    交易余额\t 收付标志\t  \
# ...

# %%
#合并文件的三种方法
#使用pathlib模块读取文件路径

from pathlib import Path
import pandas as pd
#pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'E:\3899\3899后台数据 2\5104188120210913171911').glob("*交易*.csv"))],ignore_index =True).to_csv("result.csv",index = False)

df = pd.concat([pd.concat(pd.read_csv(i,engine="python",encoding = "gbk") for i in Path(r'C:\Users\GAJ\Desktop\38手游\5104188120211009142029\5104188120211009142029').glob("*交易*.csv"))],ignore_index =True)
df.head()
# Out:
#                 交易卡号\t          交易账号\t 查询反馈结果原因\t 交易户名\t 交易证件号码\t  \
# 0  6228480178653896575  68201106303533         \t     \t       \t
# 1  6228480178653896575  68201106303533         \t     \t       \t
# 2  6228480178653896575  68201106303533         \t     \t       \t
# 3  6228480178653896575  68201106303533         \t     \t       \t
# 4  6228480178653896575  68201106303533         \t     \t       \t
#
#                   交易时间\t 交易金额\t 交易余额\t 收付标志\t              交易对手账卡号\t  ...  \
# 0  2021-02-27 12:26:13\t    0.0    0.0    出\t                     \t  ...
# 1  2021-03-06 07:14:35\t    1.0    1.0    进\t  6217855300035701816\t  ...
# 2  2021-03-06 07:19:37\t   -1.0    0.0    出\t  6217855300035701816\t  ...
# 3  2021-03-06 07:24:05\t  100.0  100.0    进\t  6217230715000365642\t  ...
# 4  2021-03-06 07:24:42\t  200.0  300.0    进\t  6212261715009932478\t  ...
#
#   对手交易余额\t 交易流水号\t      日志号\t 凭证种类\t 凭证号\t 交易柜员号\t     备注\t 商户名称\t 商户代码\t  \
# ...

# %%
#合并文件的三种方法
#使用内置的glob模块读取多个文件
from glob import glob
import pandas as pd
files = sorted(glob(r'C:\Users\GAJ\Desktop\38手游\5104188120211009142029\5104188120211009142029\*交易*.csv'))
df1=pd.concat(pd.read_csv(file,engine="python",encoding = "gbk")for file in files)
df1.head()
# Out:
#                 交易卡号\t          交易账号\t 查询反馈结果原因\t 交易户名\t 交易证件号码\t  \
# 0  6228480178653896575  68201106303533         \t     \t       \t
# 1  6228480178653896575  68201106303533         \t     \t       \t
# 2  6228480178653896575  68201106303533         \t     \t       \t
# 3  6228480178653896575  68201106303533         \t     \t       \t
# 4  6228480178653896575  68201106303533         \t     \t       \t
#
#                   交易时间\t 交易金额\t 交易余额\t 收付标志\t              交易对手账卡号\t  ...  \
# 0  2021-02-27 12:26:13\t    0.0    0.0    出\t                     \t  ...
# 1  2021-03-06 07:14:35\t    1.0    1.0    进\t  6217855300035701816\t  ...
# 2  2021-03-06 07:19:37\t   -1.0    0.0    出\t  6217855300035701816\t  ...
# 3  2021-03-06 07:24:05\t  100.0  100.0    进\t  6217230715000365642\t  ...
# 4  2021-03-06 07:24:42\t  200.0  300.0    进\t  6212261715009932478\t  ...
#
#   对手交易余额\t 交易流水号\t      日志号\t 凭证种类\t 凭证号\t 交易柜员号\t     备注\t 商户名称\t 商户代码\t  \
# ...
