# %%
#from chinese_province_city_area_mapper import drawers
import pandas as pd
import cpca
wd=pd.read_excel(r"C:\Users\23934\Downloads\batch_search.xlsx",sheet_name="Sheet6")
t=list(wd['注册地址'])
df = cpca.transform(t)
#drawers.draw_locations(df, "df.html")
#df.to_excel(r"C:\Users\23934\Desktop\彩神\分析\batch_search1.xlsx",sheet_name="cpca")

# %%
#from chinese_province_city_area_mapper import drawers
import pandas as pd
import cpca
wd=pd.read_excel(r"C:\Users\23934\Desktop\彩神\所有卡\all所有卡开户信息.xlsx",sheet_name="Sheet7")
t=list(wd['地址'])
df = cpca.transform(t)
#drawers.draw_locations(df, "df.html")
df.to_excel(r"C:\Users\23934\Desktop\彩神\所有卡\all所有卡开户信息.xlsx",sheet_name="cpca")

# %%
cpca.transform(t[0])
# Out:
#        省     市     区    地址 adcode
# 0   None  None  None  None   None
# 1   None  None  None  None   None
# 2   None  None  None  None   None
# 3   None  None  None  None   None
# 4   None  None  None  None   None
# 5   None  None  None  None   None
# 6   None  None  None  None   None
# 7   None  None  None  None   None
# 8   None  None  None  None   None
# 9   None  None  None  None   None
# 10  None  None  None  None   None
# 11  None  None  None  None   None
# 12  None  None  None  None   None
# 13  None  None  None  None   None
