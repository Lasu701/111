# %%
import pandas as pd
from datetime import datetime
df=pd.read_excel(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01.xlsx",sheet_name="Customer Information 客户信息",header=3)
#df = df.dropna()
df_t=df.iloc[0:1,:]
df_t
# Out:
#   User ID 用户ID Email 邮箱地址   Mobile 手机号码 Registration time 注册时间   Name 姓名  \
# 0    465144575        NaN  +85251602620    2022-06-02 10:50:44  郑特良 null
#
#   User nationality 国籍/地区 User ID number 身份证号码 User authentication type 账户验证类型  \
# 0                          44030619850207007X                        Personal
#
#   User authentication time 账户验证时间 Status 账户状态（是否注销） 2FA 是否2FA验证  \
# 0             2022-11-08 22:55:22            Normal      Enable
#
#   2FA Opening time 2FA认证时间  SMS 接收短信验证码的手机号 SMS Opening time  短信验证码开通时间  \
# 0                                51602620.0
#
#   2FA Reset Information 重启信息
# 0                         []

# %%
#币安Order History 现货订单记录
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sheet_name="Order History 现货订单记录")

    df_info.insert(0, "文件名", name.stem)
    
    return df_info
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安Order History 现货订单记录.xlsx",sheet_name="data",index=False)

# %%
#币安Deposit History 充值记录
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sheet_name="Deposit History 充值记录")

    df_info.insert(0, "文件名", name.stem)
    
    return df_info
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安\币安Deposit History 充值记录.xlsx",sheet_name="data",index=False)

# %%
#币安Withdrawal History 提现记录
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sheet_name="Withdrawal History 提现记录")

    df_info.insert(0, "文件名", name.stem)
    
    return df_info
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安\币安Withdrawal History 提现记录.xlsx",sheet_name="data",index=False)

# %%
#币安账户信息
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sheet_name="Customer Information 客户信息",header=3,dtype={'User ID number 身份证号码':str})
    df_info['User ID number 身份证号码']=df_info['User ID number 身份证号码'].astype(str)
    #df_info = df_info.dropna()
    df_info.insert(0, "文件名", name.stem)
    df_info=df_info.iloc[0:1,:]
    return df_info
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安账户信息.xlsx",sheet_name="data_info",index=False)

# %%
#币安P2P 法币交易
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_temp=pd.read_excel(name,sheet_name="P2P 法币交易")
    df_info=pd.read_excel(name,sheet_name="Customer Information 客户信息",header=3,dtype={'User ID number 身份证号码':str})
    df_info['User ID number 身份证号码']=df_info['User ID number 身份证号码'].astype(str)
    df_temp.insert(0, "身份证",df_info.iloc[0]['User ID number 身份证号码'])
    df_temp.insert(0, "用户id",df_info.iloc[0]['User ID 用户ID'])
    df_temp.insert(0, "文件名", name.stem)
    return df_temp
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安P2P 法币交易.xlsx",sheet_name="data",index=False)

# %%
#币安现货资产信息
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_temp=pd.read_excel(name,sheet_name="Current Assets & Wallets现货资产和钱包")
    df_info=pd.read_excel(name,sheet_name="Customer Information 客户信息",header=3,dtype={'User ID number 身份证号码':str})
    df_info['User ID number 身份证号码']=df_info['User ID number 身份证号码'].astype(str)
    df_temp.insert(0, "身份证",df_info.iloc[0]['User ID number 身份证号码'])
    df_temp.insert(0, "用户id",df_info.iloc[0]['User ID 用户ID'])
    df_temp.insert(0, "文件名", name.stem)
    return df_temp
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
#data_info["身份证"]=data_info["身份证"].astype(str)
data_info.to_excel(r"D:\项目\重庆荣昌\区块链\币安现货资产和钱包.xlsx",sheet_name="data_info",index=False)

# %%
import pandas as pd

# Replace 'path/to/file.xlsx' with the actual path to your xlsx file
df=pd.read_excel(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01.xlsx",sheet_name="Account Balance 账户余额",header=3)

end_row = df.index[df.iloc[:, 0].isna()].tolist()[0]

# Extract the data from the first table in the first sheet
table_data = df.iloc[0:end_row, :]

# Print the extracted data
table_data
# Out:
#   Currency Name 币种 Currency Code 币种代码 All Positions 全部持仓  \
# 0              ETH           Ethereum         0.00005343
#
#   Available Positions 可用持仓 In Withdrawal 提现中 Pending Order 挂单  \
# 0               0.00005343                 0                0
#
#   BTC Equivalent BTC等值资产
# 0             0.00000362

# %%
pd.options.display.float_format = '{:.6f}'.format
df
# Out:
#      Currency Name 币种  Currency Code 币种代码 All Positions 全部持仓  \
# 0                 BNB                 BNB         0.01301115
# 1                ETHW        Ethereum PoW        18.52338540
# 2                 TWT  Trust Wallet Token         0.29000000
# 3                BTTC          BitTorrent         0.20000000
# 4                 ACM  AC Milan Fan Token         0.00061800
# ...               ...                 ...                ...
# 2013         ZIL/BUSD                   -                  -
# 2014         ZIL/USDT                   -                  -
# 2015          ZRX/BTC                   -                  -
# 2016         ZRX/BUSD                   -                  -
# 2017         ZRX/USDT                   -                  -
#
#      Available Positions 可用持仓 In Withdrawal 提现中 Pending Order 挂单  \
# 0                  0.01301115                 0                0
# 1                 18.52338540                 0                0
# ...

# %%
import pandas as pd
from datetime import datetime
df_cus=pd.read_excel(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_03.xlsx",sheet_name="Customer Information 客户信息",header=3)
df_cus.columns
# Out:
# Index(['User ID 用户ID', 'Email 邮箱地址', 'Mobile 手机号码', 'Registration time 注册时间',
#        'Name 姓名', 'User nationality 国籍/地区', 'User ID number 身份证号码',
#        'User authentication type 账户验证类型', 'User authentication time 账户验证时间',
#        'Status 账户状态（是否注销）', '2FA 是否2FA验证', '2FA Opening time 2FA认证时间',
#        'SMS 接收短信验证码的手机号', 'SMS Opening time  短信验证码开通时间',
#        '2FA Reset Information 重启信息'],
#       dtype='object')

# %%
df_cus
# Out:
#                  User ID 用户ID                Email 邮箱地址    Mobile 手机号码  \
# 0                    62306290  rockllll99ooaa@gmail.com            NaN
# 1                         NaN                       NaN            NaN
# 2                         NaN                       NaN            NaN
# 3                         NaN                       NaN            NaN
# 4  API Information 应用程序编程接口信息                       NaN            NaN
# 5                Rule ID 规则ID       API Name 应用程序编程接口名称  Trade IP 交易IP
#
#   Registration time 注册时间           Name 姓名 User nationality 国籍/地区  \
# 0    2020-12-29 08:10:33   BICH NGOC HOANG
# 1                    NaN               NaN                    NaN
# 2                    NaN               NaN                    NaN
# 3                    NaN               NaN                    NaN
# 4                    NaN               NaN                    NaN
# 5       Withdraw IP 提现IP  Create Time 创建时间       Update Time 更新时间
#
# ...

# %%
idnum =df_cus.iloc[0]['User ID number 身份证号码']
name=df_cus.iloc[0]['Name 姓名']
userid=df_cus.iloc[0]['User ID 用户ID']
# Print the extracted value
print(value,name)
# Out:
# C8684211 BICH NGOC HOANG

# %%
df.insert(0, "身份证", idnum)
df.insert(0, 'User ID 用户ID',userid)

# %%
df
# Out:
#    User ID 用户ID       身份证 Currency Name 币种 Currency Code 币种代码  \
# 0      62306290  C8684211              BNB                BNB
# 1      62306290  C8684211             ETHW       Ethereum PoW
# 2      62306290  C8684211              ICP  Internet Computer
# 3      62306290  C8684211              NFT             APENFT
# 4      62306290  C8684211             AVAX          Avalanche
# 5      62306290  C8684211              FTM             Fantom
# 6      62306290  C8684211              ETH           Ethereum
# 7      62306290  C8684211               QI              BENQI
# 8      62306290  C8684211             USDT           TetherUS
# 9      62306290  C8684211              TRX               TRON
# 10     62306290  C8684211             BUSD               BUSD
#
#     All Positions 全部持仓  Available Positions 可用持仓  In Withdrawal 提现中  \
# 0           287.123930                287.123930           0.000000
# 1          1052.315900               1052.315900           0.000000
# ...

# %%
#币安账户余额
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    df = pd.read_excel(name,sheet_name="Account Balance 账户余额",header=3)
    end_row = df.index[df.iloc[:, 0].isna()].tolist()[0]
    print(name)
    print(end_row)
# Extract the data from the first table in the first sheet
    df_temp = df.iloc[0:end_row,:]
    #df_temp = df_temp.dropna()
    df_info=pd.read_excel(name,sheet_name="Customer Information 客户信息",header=3,dtype={'User ID number 身份证号码':str})
    df_info['User ID number 身份证号码']=df_info['User ID number 身份证号码'].astype(str)
    df_temp.insert(0, "身份证",df_info.iloc[0]['User ID number 身份证号码'])
    df_temp.insert(0, "用户id",df_info.iloc[0]['User ID 用户ID'])
    df_temp.insert(0, "文件名", name.stem)
    return df_temp
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\彩神\过程\彩神\427\5111057420220424163132'

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号").rglob("Report*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_balance=pd.concat(hb)
data_balance["身份证"]=data_balance["身份证"].astype(str)
data_balance.to_excel(r"D:\项目\重庆荣昌\区块链\币安.xlsx",sheet_name="data_kaihu",index=False)
# Out:
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01.xlsx
# 1
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_02.xlsx
# 17
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_03.xlsx
# 11
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_04.xlsx
# 11
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_05.xlsx
# 27
# D:\项目\重庆荣昌\重庆pk彩票\虚拟币调证\币安\BNB-26150-documents\BNB-26150_重庆市荣昌区公安局_[2023]103号\BNB-26150_重庆市荣昌区公安局_[2023]103号\Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_06.xlsx
# 4
# ...

# %%
data_balance
# Out:
#                                            文件名       用户id                 身份证  \
# 0     Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01  465144575  44030619850207007X
# 1     Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01  465144575  44030619850207007X
# 2     Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01  465144575  44030619850207007X
# 3     Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01  465144575  44030619850207007X
# 4     Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_01  465144575  44030619850207007X
# ...                                        ...        ...                 ...
# 2010  Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_10  201816488            RV079233
# 2011  Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_10  201816488            RV079233
# 2012  Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_10  201816488            RV079233
# 2013  Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_10  201816488            RV079233
# 2014  Report_BNB-26150_重庆市荣昌区公安局_[2023]103号_10  201816488            RV079233
#
# ...

# %%
#酷币账户信息
import pandas as pd
from pathlib import Path
import re
import os
def insert_name(name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sheet_name="CustomerInformation")
    
    
    df_info.insert(0, "文件名", name.stem)
   
    return df_info
# 合并csv文件
data=[]
hb=[]
#path=r'C:\Users\23934\Desktop\

    
for index,name in enumerate(Path(r"D:\项目\重庆荣昌\区块链\返回流水\库币1").rglob("*.xlsx")):
    #print(name)
    df=insert_name(name)
    hb.append(df)
data_info=pd.concat(hb)
with pd.ExcelWriter(r'') as writer:
        data_kaihu.to_excel(writer, sheet_name="data_kaihu",index=False)  
        data_kh_qka.to_excel(writer, sheet_name="data_kh_qka",index=False)
# data_info.to_excel(r"D:\项目\重庆荣昌\区块链\酷币账户信息.xlsx",sheet_name="data",index=False)

# %%
import pandas as pd
from pathlib import Path
import re
import os
files=pd.ExcelFile(r"D:\项目\重庆荣昌\区块链\返回流水\库币1\ndjfjsjdn89@gmail.com.xlsx")
tab_names=files.sheet_names
def insert_name(name,sh_name):
    # 为csv文件添加文件名列
    
    df_info=pd.read_excel(name,sh_name)
    
    
    df_info.insert(0, "文件名", name.stem)
   
    return df_info
# 合并csv文件

#path=r'C:\Users\23934\Desktop\

for i in tab_names:
    hb=[]
    print(i)
    for index,name in enumerate(Path(r"D:\项目\重庆荣昌\区块链\返回流水\库币1").rglob("*.xlsx")):
        #print(name)
   
        df=insert_name(name,i)
        hb.append(df)
    data=pd.concat(hb)
#     with pd.ExcelWriter(r'D:\项目\重庆荣昌\区块链\酷币\酷币信息.xlsx') as writer:
#         data.to_excel(writer, sheet_name=i, index=False)
    with pd.ExcelWriter(r'D:\项目\重庆荣昌\区块链\酷币\酷币信息.xlsx', mode='a', engine='openpyxl') as writer:
        data.to_excel(writer, sheet_name=i, index=False)
        #data_kh_qka.to_excel(writer, sheet_name="data_kh_qka",index=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# CustomerInformation
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# CurrentAssets
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13704\3897991560.py in <module>
#       1 files=pd.ExcelFile(r"D:\项目\重庆荣昌\区块链\返回流水\库币1\ndjfjsjdn89@gmail.com.xlsx")
#       2 tab_names=files.sheet_names
# ----> 3 tab_names.dtypes
#
# AttributeError: 'list' object has no attribute 'dtypes'
